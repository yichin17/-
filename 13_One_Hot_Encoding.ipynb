# %% [markdown]
# <a href="https://colab.research.google.com/github/yichin17/LLM/blob/main/13_One_Hot_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
country=['Taiwan','Australia','Ireland','Australia','Ireland','Taiwan']
age=[25,30,45,35,22,36]
salary=[20000,32000,59000,60000,43000,52000]
dic={'Country':country,'Age':age,'Salary':salary}
data=pd.DataFrame(dic)
data
# Out:
#      Country  Age  Salary
# 0     Taiwan   25   20000
# 1  Australia   30   32000
# 2    Ireland   45   59000
# 3  Australia   35   60000
# 4    Ireland   22   43000
# 5     Taiwan   36   52000

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data_le=pd.DataFrame(dic)
data_le['Country'] = labelencoder.fit_transform(data['Country'])
data_le
# Out:
#    Country  Age  Salary
# 0        2   25   20000
# 1        0   30   32000
# 2        1   45   59000
# 3        0   35   60000
# 4        1   22   43000
# 5        2   36   52000

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("Country", OneHotEncoder(), [0])], remainder = 'passthrough')
data_str_ohe=ct.fit_transform(data_le)
pd.DataFrame(data_str_ohe)
# Out:
#      0    1    2     3        4
# 0  0.0  0.0  1.0  25.0  20000.0
# 1  1.0  0.0  0.0  30.0  32000.0
# 2  0.0  1.0  0.0  45.0  59000.0
# 3  1.0  0.0  0.0  35.0  60000.0
# 4  0.0  1.0  0.0  22.0  43000.0
# 5  0.0  0.0  1.0  36.0  52000.0

# %%
data_dum = pd.get_dummies(data)
pd.DataFrame(data_dum)
# Out:
#    Age  Salary  Country_Australia  Country_Ireland  Country_Taiwan
# 0   25   20000                  0                0               1
# 1   30   32000                  1                0               0
# 2   45   59000                  0                1               0
# 3   35   60000                  1                0               0
# 4   22   43000                  0                1               0
# 5   36   52000                  0                0               1
